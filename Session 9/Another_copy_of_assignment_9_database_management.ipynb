# %% [markdown]
# <a href="https://colab.research.google.com/github/caplescia/MPM_200_Plescia/blob/main/Session%209/Another_copy_of_assignment_9_database_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Packages and Scientific Computing Libraries
#
# """
# Python Packages Overview:
# -------------------------
# Packages in Python are collections of modules that provide reusable code and functionality.
# They allow developers to organize and share complex code libraries that can be easily imported
# and used across different projects.
#
# Key Characteristics of Packages:
# - Organized hierarchically
# - Contain multiple related modules
# - Can be installed using package managers like pip
# - Extend Python's core functionality
#
# Three Essential Data Science Libraries:
# --------------------------------------
# 1. Pandas (pd):
#    - Primary library for data manipulation and analysis
#    - Provides DataFrame: a 2D labeled data structure with columns of potentially different types
#    - Key Features:
#      * Reading/writing data from various sources (CSV, Excel, SQL databases)
#      * Data cleaning and preprocessing
#      * Complex data transformations
#      * Powerful data analysis and aggregation tools
#
# 2. NumPy (np):
#    - Fundamental package for scientific computing in Python
#    - Introduces the ndarray (n-dimensional array) for efficient numerical operations
#    - Key Features:
#      * High-performance multidimensional array object
#      * Mathematical and statistical functions
#      * Linear algebra operations
#      * Foundation for scientific and numerical computing
#      * Enables fast computations on large datasets
#
# 3. Matplotlib (plt):
#    - Comprehensive library for creating static, animated, and interactive visualizations
#    - Provides MATLAB-like plotting interface
#    - Key Features:
#      * Line plots, scatter plots, bar charts, histograms
#      * Customizable plot styles and layouts
#      * Support for multiple plot types and graph formats
#      * Integration with NumPy for data visualization
#
# Practical Significance:
# ----------------------
# These libraries form the backbone of data science and scientific computing in Python,
# enabling complex data analysis, numerical computations, and insightful visualizations
# with minimal code.
# """

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the Excel file
flavivirus_df = pd.read_excel("/content/Flavivirus host associations.xlsx")

# Display basic information about the dataset
print(flavivirus_df.info())

# Show the first few rows of the data
flavivirus_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sr no.                  570 non-null    int64
#  1   Virus                   570 non-null    object
#  2   Scientific Name         570 non-null    object
#  3   Authors                 570 non-null    object
#  4   Year                    430 non-null    object
#  5   Title/accession number  570 non-null    object
#  6   Journal                 425 non-null    object
#  7   Issue                   415 non-null    float64
#  8   Volume                  404 non-null    object
#  9   Pages                   404 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 44.7+ KB
# None
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# 1       2    Apoi virus    Myodes rufocanus
# ...

# %% [markdown]
# ## Using pandas functions that you have seen in the class address following questions
# 1. How many entries are there in the dataset?
# 2. How many viruses are present in the dataset?
# 3. List those viruses.
# 4. How many rows of data are present for each virus?
# 5. How many host species are present in the data?
# 6. Make a list of host species present.
# 7. Count the number of unique host species for each virus.
# 8. Which virus has the most number of hosts?
# 9. Which host has most number of viruses?

# %%
# Exploring Virus and Species Diversity in the Dataset
flavivirus_df.columns.tolist()
num_viruses = flavivirus_df['Virus'].nunique()
num_hosts = flavivirus_df['Scientific Name'].nunique()

print(f"Number of unique viruses: {num_viruses}")
print(f"Number of unique host species: {num_hosts}")

# Count total number of entries in the dataset
total_entries = flavivirus_df.shape[0]
print(f"Total number of entries: {total_entries}")


# Count of unique viruses
unique_viruses = flavivirus_df['Virus'].nunique()
print(f"Number of unique viruses: {unique_viruses}")

# List of unique viruses
unique_viruses = flavivirus_df['Virus'].unique()
print (unique_viruses)

# Count of each unique virus
virus_counts = flavivirus_df['Virus'].value_counts()
print(virus_counts)

# Count unique host species
unique_hosts = flavivirus_df['Scientific Name'].nunique()
print(f"Number of unique hosts: {unique_hosts}")

# List of unique host species
unique_hosts = flavivirus_df['Scientific Name'].unique()
print (unique_hosts)

# Count of host species for each virus
virus_host_counts = flavivirus_df.groupby('Virus')['Scientific Name'].nunique()
print(virus_host_counts)

# Most diverse viruses (viruses with most unique host species)
virus_host_counts = flavivirus_df.groupby('Virus')['Scientific Name'].nunique()

virus_host_counts_sorted = virus_host_counts.sort_values(ascending=False)

print(virus_host_counts_sorted.head(5))  # Top 5 viruses with most unique hosts
# Out:
# Number of unique viruses: 30
# Number of unique host species: 419
# Total number of entries: 570
# Number of unique viruses: 30
# ['Apoi virus' 'Bagaza virus' 'Banzi virus' 'Bouboui virus'
#  'Bussuquara virus' 'Cacipacore virus' 'Dakar bat virus' 'Dengue virus'
#  'Entebbe bat virus' 'Iguape virus' 'Ilheus virus'
#  'Japanese encephalitis virus' 'Koutango virus' 'Kunjin virus'
#  'Kyasanur forest virus' 'Louping-ill virus' 'Modoc virus'
#  'Murray Valley encephalitis virus' 'Omsk hemorrhagic fever virus'
#  'Rio Bravo virus' 'Rocio virus' 'St. Louis Encephalitis virus'
#  'Tembusu virus' 'Tickborne encephalitis virus' 'Uganda S virus'
#  'Usutu virus' 'Wesselsbron virus' 'West Nile virus' 'Yellow fever virus'
#  'Zika virus']
# Virus
# West Nile virus                     194
# Tickborne encephalitis virus         84
# St. Louis Encephalitis virus         72
# Usutu virus                          65
# Dengue virus                         27
# Japanese encephalitis virus          25
# ...

# %% [markdown]
# # Metadata
#
# ## Given that we are interested in the metadata associated with these host species, we will import datasets associated with the metadata for both bird and mammalian species.

# %% [markdown]
# 1. Birds

# %%
birds_meta = pd.read_excel("/content/Handbook of the Birds of the World and BirdLife International Digital Checklist of the Birds of the World_Version_9.xlsx")
birds_meta.head()
# Out:
#    Seq.  Subsp. Seq.             Order    Family name     Family Subfamily  \
# 0   1.0          0.0  STRUTHIONIFORMES  Struthionidae  Ostriches       NaN
# 1   1.0          1.0               NaN            NaN        NaN       NaN
# 2   1.0          2.0               NaN            NaN        NaN       NaN
# 3   1.0          3.0               NaN            NaN        NaN       NaN
# 4   1.0          4.0               NaN            NaN        NaN       NaN
#
#   Tribe     Common name             Scientific name       Authority  \
# 0   NaN  Common Ostrich            Struthio camelus  Linnaeus, 1758
# 1   NaN             NaN   Struthio camelus syriacus             NaN
# 2   NaN             NaN    Struthio camelus camelus             NaN
# 3   NaN             NaN  Struthio camelus massaicus             NaN
# 4   NaN             NaN  Struthio camelus australis             NaN
#
#   2024 IUCN Red List category Synonyms Alternative common names  \
# ...

# %%
birds_meta.shape
# Out:
# (33265, 17)

# %%
#species level rows only
species_only = birds_meta[birds_meta["Subsp. Seq."] == 0]

# %%
species_count = (birds_meta["Subsp. Seq."] == 0).sum()
print(species_count)
# Out:
# 11204

# %%
birds_meta = species_only[['Scientific name', 'Order', 'Family name']].copy()
birds_meta = birds_meta.rename(columns={'Scientific name': 'Scientific Name', 'Family name': 'Family'})
birds_meta ['Class'] = 'Aves'

# %%
#Group subspecies by species
species_groups = birds_meta.groupby("Scientific Name")

# %%
#How many subspecies does each species have
subspecies_counts = birds_meta.groupby("Scientific Name").size()
print(subspecies_counts)
# Out:
# Scientific Name
# Abeillia abeillei            1
# Abroscopus albogularis       1
# Abroscopus schisticeps       1
# Abroscopus superciliaris     1
# Aburria aburri               1
#                             ..
# Zosterornis hypogrammicus    1
# Zosterornis latistriatus     1
# Zosterornis nigrorum         1
# Zosterornis striatus         1
# Zosterornis whiteheadi       1
# Length: 11198, dtype: int64

# %% [markdown]
# The data for birds is at subspecies level. It means that there is species name represented by column `Seq.`. All rows in same number represent one species.

# %% [markdown]
# 2. Mammals

# %% [markdown]
# ## Similarly, read file for mammals metadata.

# %%
import pandas as pd

mammals_meta = pd.read_csv(
    "/content/IUCN Mammals, Birds, Reptiles, and Amphibians.csv",
    encoding="latin1"
)

mammals_meta.head()
# Out:
#    Species ID   Kingdom    Phylum     Class             Order       Family  \
# 0     42641.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 1  22687170.0  ANIMALIA  CHORDATA      AVES  CAPRIMULGIFORMES  TROCHILIDAE
# 2     17879.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 3  47760825.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA   CRICETIDAE
# 4     42656.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA  ABROCOMIDAE
#
#           Genus    Species                  Authority  Infraspecific rank  \
# 0     Abditomys   latidens            (Sanborn, 1952)                 NaN
# 1      Abeillia   abeillei  (Lesson & DeLattre, 1839)                 NaN
# 2   Abeomelomys      sevia    (Tate & Archbold, 1935)                 NaN
# 3  Abrawayaomys    ruschii         Cunha & Cruz, 1979                 NaN
# 4      Abrocoma  bennettii           Waterhouse, 1837                 NaN
#
#    ...                             Synonyms  \
# ...

# %%
mammals_meta.shape
# Out:
# (16081, 23)

# %%
filtered_mammals = mammals_meta[mammals_meta['Class'] == 'MAMMALIA']
filtered_mammals = mammals_meta[['Species', 'Order', 'Family', 'Class']].copy()
filtered_mammals = filtered_mammals.rename(columns={'Species': 'Scientific Name'})

# %%
filtered_mammals
# Out:
#          Scientific Name             Order       Family     Class
# 0               latidens          RODENTIA      MURIDAE  MAMMALIA
# 1               abeillei  CAPRIMULGIFORMES  TROCHILIDAE      AVES
# 2                  sevia          RODENTIA      MURIDAE  MAMMALIA
# 3                ruschii          RODENTIA   CRICETIDAE  MAMMALIA
# 4              bennettii          RODENTIA  ABROCOMIDAE  MAMMALIA
# ...                  ...               ...          ...       ...
# 16076              pacos   CETARTIODACTYLA    CAMELIDAE  MAMMALIA
# 16077                NaN     PASSERIFORMES    STURNIDAE      AVES
# 16078                NaN          RODENTIA      MURIDAE  MAMMALIA
# 16079  scrofa domesticus   CETARTIODACTYLA       SUIDAE  MAMMALIA
# 16080              pamfi          RODENTIA      MURIDAE  MAMMALIA
#
# [16081 rows x 4 columns]

# %%
total_mammal_species = filtered_mammals['Scientific Name'].nunique()
print(total_mammal_species)
# Out:
# 8779

# %% [markdown]
# ## For both birds and mammals answer the following questions.
# 1. Size of the datasets
# 2. For birds, filter the dataset using species-level rows only. Hint. Column `Subsp. Seq.` value of 0 indicates the main species name
# 3. How many bird species and mammal species are present in data frames?

# %% [markdown]
# 1.  For the birds:  the dataset size is (33265, 17).  For the mammals:  the dataset size is (16081, 23).
# 2.  see code
# 3.  There are 11,204 bird species.  There are 8779 mammal species.

# %% [markdown]
# # Database Integration Exercise
# The main objective of this exercise is to create a comprehensive database by combining three data frames. Follow these steps  n your analysis.

# %% [markdown]
# ## Create a concept map:
# * Illustrate the relationships between the three data frames.
# * Identify and highlight the Primary Keys in each data frame.
# * Use a diagramming tool (e.g., PowerPoint, LucidChart, or Draw.io) to create a visual representation of these connections.
# * Pay special attention to how you plan to merge the Mammals and Birds data frames.

# %% [markdown]
# ![conceptmap.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Perform a vertical join of Mammals and Birds data frames:
# * Identify and select only the common columns present in both data frames.
# * Use `pd.concat()` or `df.append()` to create a larger dataframe called **metadata**.
# * Ensure the resulting dataframe has the correct number of rows and columns.

# %%
# Find common columns
common_cols = filtered_mammals.columns.intersection(birds_meta.columns)

# Subset both dataframes to only common columns
mammals_common = filtered_mammals[common_cols]
birds_common = birds_meta[common_cols]

# Vertically concatenate
metadata = pd.concat([mammals_common, birds_common], ignore_index=True)

# Check shape
print("Rows, Columns:", metadata.shape)
metadata.head()
# Out:
# Rows, Columns: (27285, 4)
#   Scientific Name             Order       Family     Class
# 0        latidens          RODENTIA      MURIDAE  MAMMALIA
# 1        abeillei  CAPRIMULGIFORMES  TROCHILIDAE      AVES
# 2           sevia          RODENTIA      MURIDAE  MAMMALIA
# 3         ruschii          RODENTIA   CRICETIDAE  MAMMALIA
# 4       bennettii          RODENTIA  ABROCOMIDAE  MAMMALIA

# %% [markdown]
# ## Merge the metadata dataframe with the Flavivirus dataframe:
# * Experiment with different join types: `inner`, `outer`, `left`, and `right`.
# * For each join type, record the resulting dataframe's shape (rows and columns).
# * Determine the **theoretically correct size of the merged dataframe if done manually**.
# * Compare the results of each join type with the expected outcome.
# * Choose the most appropriate join type based on your analysis.

# %%
# Find common columns between the two dataframes
metadata.columns.intersection(flavivirus_df.columns)
# Out:
# Index(['Scientific Name'], dtype='object')

# %%
metadata.columns
# Out:
# Index(['Scientific Name', 'Order', 'Family', 'Class'], dtype='object')

# %%
common_columns_set = set(flavivirus_df.columns).intersection(set(metadata.columns))

# %%
print(len(common_columns_set))
# Out:
# 1

# %%
# The birds_meta dataframe (from the previous processing step in cell 0h6U19vtohe1)
# already contains species-level data with 'Scientific Name', 'Order', 'Family', 'Class'.
# We can directly use this for the merge, renaming the 'Scientific Name' column.
birds_species_df = birds_meta[['Scientific Name', 'Order', 'Family']].copy()
birds_species_df.rename(columns={'Scientific Name': 'Scientific_Name_Host'}, inplace=True)

filtered_mammals_df = mammals_meta[mammals_meta['Class'] == 'MAMMALIA'].copy()
mammals_species_df = filtered_mammals_df[['Species', 'Order', 'Family']].copy()
mammals_species_df.rename(columns={'Species': 'Scientific_Name_Host'}, inplace=True)

metadata_for_merge = pd.concat([birds_species_df, mammals_species_df], ignore_index=True)

first_merge = pd.merge(
    flavivirus_df,
    metadata_for_merge,
    left_on='Scientific Name',
    right_on='Scientific_Name_Host',
    how='left'
)
print("Shape of the merged dataframe:", first_merge.shape)
first_merge.head()
# Out:
# Shape of the merged dataframe: (570, 13)
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# 1       2    Apoi virus    Myodes rufocanus
# 2       0    Apoi virus  Apodemus argenteus
# 3       1    Apoi virus  Apodemus speciosus
# 4       4  Bagaza virus      Alectoris rufa
#
#                                              Authors  Year  \
# 0  C. M. Baak-Baak, N. Cigarroa-Toledo, O. M. Tor...  2016
# 1                                        CDC Arbocat   NaN
# 2                 J. S. Mackenzie and D. T. Williams  2009
# 3                 J. S. Mackenzie and D. T. Williams  2009
# 4  D. Buitrago, A. Rocha, C. Tena-Tomas, M. Vigo,...  2012
#
#                               Title/accession number  \
# 0  New Records of Ectoparasites Echinolaelaps ech...
# 1                                        CDC Arbocat
# 2  The zoonotic flaviviruses of southern, south-e...
# 3  The zoonotic flaviviruses of southern, south-e...
# ...

# %%
first_merge.shape
# Out:
# (570, 13)

# %%
outer_merge = pd.merge (
    flavivirus_df,
    metadata_for_merge,
    left_on='Scientific Name',
    right_on='Scientific_Name_Host',
    how='outer'
)

# %%
outer_merge.shape
# Out:
# (17161, 13)

# %%
outer_merge.head()
# Out:
#    sr no. Virus Scientific Name Authors Year Title/accession number Journal  \
# 0     NaN   NaN             NaN     NaN  NaN                    NaN     NaN
# 1     NaN   NaN             NaN     NaN  NaN                    NaN     NaN
# 2     NaN   NaN             NaN     NaN  NaN                    NaN     NaN
# 3     NaN   NaN             NaN     NaN  NaN                    NaN     NaN
# 4     NaN   NaN             NaN     NaN  NaN                    NaN     NaN
#
#    Issue Volume Pages      Scientific_Name_Host             Order  \
# 0    NaN    NaN   NaN         Abeillia abeillei  CAPRIMULGIFORMES
# 1    NaN    NaN   NaN    Abroscopus albogularis     PASSERIFORMES
# 2    NaN    NaN   NaN    Abroscopus schisticeps     PASSERIFORMES
# 3    NaN    NaN   NaN  Abroscopus superciliaris     PASSERIFORMES
# 4    NaN    NaN   NaN            Aburria aburri       GALLIFORMES
#
#           Family
# 0    Trochilidae
# 1  Scotocercidae
# 2  Scotocercidae
# 3  Scotocercidae
# 4       Cracidae

# %% [markdown]
# ### Create a pivote table,
# 1. Rows are virueses
# 2. Columns are Taxonomic orders
# 3. Values are number of unique host species

# %%
pivot = pd.pivot_table(
    first_merge,
    index="Virus",          # rows
    columns="Scientific Name",        # columns
    values="Scientific_Name_Host",  # column with host names (corrected from 'Host_Species')
    aggfunc=pd.Series.nunique,
    fill_value=0
)

pivot
# Out:
# Scientific Name                   Accipiter cooperii  Accipiter gentilis  \
# Virus
# Apoi virus                                         0                   0
# Bagaza virus                                       0                   0
# Banzi virus                                        0                   0
# Bouboui virus                                      0                   0
# Bussuquara virus                                   0                   0
# Cacipacore virus                                   0                   0
# Dakar bat virus                                    0                   0
# Dengue virus                                       0                   0
# Entebbe bat virus                                  0                   0
# Iguape virus                                       0                   0
# Ilheus virus                                       0                   0
# Japanese encephalitis virus                        0                   0
# ...

# %%
pivot = pd.pivot_table(
    outer_merge,
    index="Virus",          # rows
    columns="Scientific Name",        # columns
    values="Scientific_Name_Host",  # column with host names (corrected from 'Host_Species')
    aggfunc=pd.Series.nunique,
    fill_value=0
)

pivot
# Out:
# Scientific Name                   Accipiter cooperii  Accipiter gentilis  \
# Virus
# Apoi virus                                         0                   0
# Bagaza virus                                       0                   0
# Banzi virus                                        0                   0
# Bouboui virus                                      0                   0
# Bussuquara virus                                   0                   0
# Cacipacore virus                                   0                   0
# Dakar bat virus                                    0                   0
# Dengue virus                                       0                   0
# Entebbe bat virus                                  0                   0
# Iguape virus                                       0                   0
# Ilheus virus                                       0                   0
# Japanese encephalitis virus                        0                   0
# ...
